# %% [markdown]
# TYPE CASTING

# %%
a=4
b=1.0
c="name"
d=True

# %%
float(a)
# Out:
# 4.0

# %%
str(a)
# Out:
# '4'

# %%
bool(a)
# Out:
# True

# %%
int(b)
# Out:
# 1

# %%
int(a)
# Out:
# 4

# %%
str(c)
# Out:
# 'name'

# %%
bool(d)
# Out:
# True

# %%
int(d)
# Out:
# 1

# %%
a="123"
int(a)
# Out:
# 123

# %%
x="hello"
y="123"
z="2.3"

# %%
float(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 float(x)
#
# ValueError: could not convert string to float: 'hello'

# %%
float(y)
# Out:
# 123.0

# %%
float(z)
# Out:
# 2.3

# %%
str(d)
# Out:
# 'True'

# %%
int(d)
# Out:
# 1

# %%
float(d)
# Out:
# 1.0

# %% [markdown]
# ARITHMETIC OPERATORS

# %%
23+24
# Out:
# 47

# %%
24-23
# Out:
# 1

# %%
0/24
# Out:
# 0.0

# %%
25%24
# Out:
# 1

# %%
24*12
# Out:
# 288

# %% [markdown]
# COMPARISION OPERATOR

# %%
a=23
b=24

# %%
a==b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
a>b
# Out:
# False

# %%
a<b
# Out:
# True

# %%
a>=b
# Out:
# False

# %%
a<=b
# Out:
# True

# %% [markdown]
# LOGICAL OPERATOR

# %% [markdown]
# AND

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
False and False
# Out:
# False

# %% [markdown]
# OR

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or True
# Out:
# True

# %%
False or False
# Out:
# False

# %% [markdown]
# MEMBERSHIP OPERATOR

# %%
"a" in "apple"
# Out:
# True

# %%
"a" not in "apple"
# Out:
# False

# %%
"souri" in "rakshitha"
# Out:
# False

# %% [markdown]
# CONDITIONAL STATEMENTS

# %% [markdown]
# IF STATMENT

# %%
age = 20
if (age>=18):
    print("eligible to vote")
# Out:
# eligible to vote

# %%
age=16
if(age>=18):
    print("eligible to vote")
print("Welcome")
# Out:
# Welcome

# %%
height=50
if(height>=150):
    print("eligible for sports")
print("Thank you")
# Out:
# Thank you

# %% [markdown]
# INPUT FUN

# %%
a=input("enter the name")
# Out:
# enter the name Rakshitha

# %%
a=input("enter the name")
# Out:
# enter the name 10

# %%
b=int(input("enter your age"))
# Out:
# enter your age 22

# %%
b=int(input("enter your age"))
# Out:
# enter your age baa
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 b=int(input("enter your age"))
#
# ValueError: invalid literal for int() with base 10: 'baa'

# %%
age=int(input("enter the age"))
if(age>=18):
    print("eligible to vote")
print("Welcome")
# Out:
# enter the age 20
# eligible to vote
# Welcome

# %%
a=5
b=6
if a==b:
    print("equal")
if a!=b:
    print("not equal")
# Out:
# not equal

# %%
a=5
b=6
if a==b:
    print("True")
if a!=b:
    print("False")
# Out:
# False

# %% [markdown]
# IF ELSE STATEMENT

# %%
age=int(input("enter the age"))
age = 25
if (age>=18):
   print("eligible to vote")
else:
   print("not eligible to vote")
# Out:
# enter the age 20
# eligible to vote

# %%
height=int(input("enter the height"))
height=160
if(height>=150):
    print("eligible for sports")
else:
    print("not eligible for sports")
print("welcome")
# Out:
# enter the height 150
# eligible for sports
# welcome

# %% [markdown]
# IF-ELSE-IF STATEMENT

# %%
x=int(input("enter the number"))
if x>0:
    print("positive number")
elif x<0:
    print("negative number")
else:
    print("natural")
# Out:
# enter the number 5
# positive number

# %%
marks=int(input("enter your marks:"))
if marks>=85:
    print("distinction")
elif marks>=60:
    print("first class")
elif marks>=40:
    print("pass")
else:
    print("fail")
# Out:
# enter your marks: 35
# fail

# %% [markdown]
# NESTED-IF-ELSE STATEMENT

# %%
citizenship=input("enter your country:")
age=int(input("enter your age:"))
if citizenship=="India" or "Indian":
    if age>=18:
        print("you are eligible to vote")
    else:
        print("you are not eligible to vote")
else:
    print("you are not an indian")
# Out:
# enter your country: India
# enter your age: 20
# you are eligible to vote

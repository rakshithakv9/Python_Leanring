# %% [markdown]
# Packages

# %%
import datetime

# %%
now=datetime.datetime.now()

# %%
now
# Out:
# datetime.datetime(2025, 12, 22, 14, 12, 37, 569948)

# %%
today=datetime.date.today()

# %%
today
# Out:
# datetime.date(2025, 12, 22)

# %%
today=datetime.datetime.now()

# %%
today
# Out:
# datetime.datetime(2025, 12, 22, 14, 14, 34, 884819)

# %%
from datetime import date
present=date(2025,12,22)

# %%
present.month
# Out:
# 12

# %%
present.year
# Out:
# 2025

# %%
present.day
# Out:
# 22

# %%
from datetime import timedelta

# %%
future=present+timedelta(days=720)

# %%
future
# Out:
# datetime.date(2027, 12, 12)

# %%
past=present-timedelta(days=720)

# %%
past
# Out:
# datetime.date(2024, 1, 2)

# %% [markdown]
# Data Structure types

# %% [markdown]
# 1.List

# %%
nums=[1,2,3,4,5]
fruits=["apple","banana","mango"]
alpha_num=[1,2,3,"apple","mango",2.4]
list=[]

# %%
alpha_num[-3]#reversing
# Out:
# 'apple'

# %%
fruits[2]#indexing
# Out:
# 'mango'

# %%
alpha_num[5]#indexing
# Out:
# 2.4

# %%
type(nums)#data type
# Out:
# list

# %%
len(nums)#length
# Out:
# 5

# %%
alpha_num[3:5]#slicing
# Out:
# ['apple', 'mango']

# %%
alpha_num[0:5:2]#slicing
# Out:
# [1, 3, 'mango']

# %%
alpha_num.insert(3,"orange")

# %%
alpha_num
# Out:
# [1, 2, 3, 'orange', 'apple', 'mango', 2.4]

# %%
alpha_num.remove(3)

# %%
alpha_num
# Out:
# [1, 2, 'orange', 'apple', 'mango', 2.4]

# %% [markdown]
# List another example

# %%
a=[1,2,12,23,23,3,4.3]

# %%
a
# Out:
# [1, 2, 12, 23, 23, 3, 4.3]

# %%
a.remove(23)

# %%
a
# Out:
# [1, 2, 12, 23, 3, 4.3]

# %%
min(a)
# Out:
# 1

# %%
max(a)
# Out:
# 23

# %%
"23" in "a"
# Out:
# False

# %%
"23" not in "a"
# Out:
# True

# %%
a
# Out:
# [1, 2, 12, 23, 3, 4.3]

# %%
a.sort()

# %%
a
# Out:
# [1, 2, 3, 4.3, 12, 23]

# %%
a.append(25)

# %%
a
# Out:
# [1, 2, 3, 4.3, 12, 23, 25]

# %%
a.extend([7,9,20])

# %%
a
# Out:
# [1, 2, 3, 4.3, 12, 23, 25, 7, 9, 20]

# %%
a.reverse()

# %%
a
# Out:
# [20, 9, 7, 25, 23, 12, 4.3, 3, 2, 1]

# %%
a[::-1]
# Out:
# [1, 2, 3, 4.3, 12, 23, 25, 7, 9, 20]

# %%
a.clear()

# %%
a
# Out:
# []

# %%
del a

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
a=5
b=5
a==b
a is b
# Out:
# True

# %% [markdown]
# Nested list

# %%
a=[1,2,[3,4],[5,6]]

# %%
a
# Out:
# [1, 2, [3, 4], [5, 6]]

# %%
a[2][0]
# Out:
# 3

# %%
a[3][1]
# Out:
# 6

# %%
a=[1,2,12,23,23,3,4.3]
b=[45,46,67,78,89]

# %%
a+b
# Out:
# [1, 2, 12, 23, 23, 3, 4.3, 45, 46, 67, 78, 89]

# %%
a[0]=4#exchange or updating value

# %%
a
# Out:
# [4, 2, 12, 23, 23, 3, 4.3]

# %%
Tuples
# it is immutable it doesn't change and update anything
#it is similar to list

# %%
t=(23,3,4,5,6,7)

# %%
t
# Out:
# (23, 3, 4, 5, 6, 7)

# %%
"3" in "t"
# Out:
# False

# %%
"3"not in "t"
# Out:
# True

# %%
t.count(23)
# Out:
# 1

# %%
t.index(23)
# Out:
# 0

# %%
t[0]
# Out:
# 23

# %%
t[0]=24
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 t[0]=24
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1=(23,34,45,46)

# %%
t+t1
# Out:
# (23, 3, 4, 5, 6, 7, 23, 34, 45, 46)

# %%
t2=(1,2,(3,5),(23,54))

# %%
t2
# Out:
# (1, 2, (3, 5), (23, 54))

# %% [markdown]
# Sets
# #it is unordered collection ,it can have a unique values.
# it is mutable values

# %%
s={2,3,34,34,45,56}

# %%
s
# Out:
# {2, 3, 34, 45, 56}

# %%
s.add(8)#adding a values

# %%
s
# Out:
# {2, 3, 5, 8, 34, 45, 56}

# %%
s.pop()
# Out:
# 2

# %%
s
# Out:
# {3, 5, 8, 34, 45, 56}

# %%
s.pop()
# Out:
# 3

# %%
s
# Out:
# {5, 8, 34, 45, 56}

# %%
s.remove(5)

# %%
s
# Out:
# {8, 34, 45, 56}

# %%
sets1={2,3,4,5,6}
sets2={34,4,5,26,67,78}

# %%
sets1.union(sets2)
# Out:
# {2, 3, 4, 5, 6, 26, 34, 67, 78}

# %%
sets1.intersection(sets2)
# Out:
# {4, 5}

# %%
sets1.difference(sets2)
# Out:
# {2, 3, 6}

# %%
sets1.pop()
# Out:
# 2

# %%
sets1.add(1)

# %%
sets1
# Out:
# {1, 3, 4, 5, 6}

# %%
sets2.remove(4)

# %%
sets2
# Out:
# {5, 26, 34, 67, 78}

# %%
sets2.discard(100)

# %%
sets2
# Out:
# {4, 5, 26, 34, 67, 78}

# %%
type(sets1)
# Out:
# set

# %%
len(sets2)
# Out:
# 5

# %% [markdown]
# Dictionary
# #it is collection of keys and values

# %%
dict={"name":"rakshitha","age":21,"id":"E34"}

# %%
dict
# Out:
# {'name': 'rakshitha', 'age': 21, 'id': 'E34'}

# %%
dict.keys()
# Out:
# dict_keys(['name', 'age', 'id'])

# %%
dict.values()
# Out:
# dict_values(['rakshitha', 21, 'E34'])

# %%
dict.update({"name":"Rachu"})

# %%
dict
# Out:
# {'name': 'Rachu', 'age': 21, 'id': 'E34'}

# %%
dict.update({"dob":"12-3-2004"})

# %%
dict.get("name")
# Out:
# 'Rachu'

# %%
dict
# Out:
# {'name': 'Rachu', 'age': 21, 'id': 'E34', 'dob': '12-3-2004'}

# %%
dict.pop("name")
# Out:
# 'Rachu'

# %%
dict
# Out:
# {'age': 21, 'id': 'E34', 'dob': '12-3-2004'}

# %%
dict.clear()

# %%
dict
# Out:
# {}

# %%
del dict

# %%
dict
# Out:
# dict

# %%
dict.items
# Out:
# <method 'items' of 'dict' objects>

# %% [markdown]
# #PYTHON itroduction

# %%
45+98
# Out:
# 143

# %%
a=5
b=6
a+b
# Out:
# 11

# %%
a
# Out:
# 5

# %%
b
# Out:
# 6

# %%
a/b
# Out:
# 0.8333333333333334

# %%
x=60
y=70
z=80

# %% [markdown]
# #IDENTIFIERS:
# *an identifier is the name given toentities like functions,variables etc
# *it helps in differentiating one entity from other.

# %%
age1=24

# %%
age1
# Out:
# 24

# %%
---
Correct way of defining an identifier 
(Identifier can be a combination of letters in lowercase (a to z) or uppercase
and only special character allowed is _ )---

var = 2
# var is entity called as variable has been created and assigned with value of 2

# %%
var=4
print(var)
# Out:
# 4

# %%
var_12='data'

# %% [markdown]
# #KEYWORDS
# IN PYTHON ARE RESERVE WORDS IN PYTHON AND CANT BE USED AS IDENTIFIERS.

# %%
print("Hello world")
# Out:
# Hello world

# %%
import keyword#this is python code for keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
#this is a variable storing value as 10
val2=10
print(val2)
# Out:
# 10

# %% [markdown]
# #COMMENTS
# *comments can be used to explain the code for more readability
# a.single line comment => #this is a block
# b.double line comment => #this is a block
#                          #that spans across multiple lines
# c.multi line commnt => """
#                         this is also a multi-line comment.
#                         it is a string literal not assigned to a variable.
#                       """

# %% [markdown]
# Name="sneha"

# %%
'''multi line comments
sum of two numbers'''
a=5
b=10
a+b
# Out:
# 15

# %%
a,b=10,4

# %%
a
# Out:
# 10

# %%
b
# Out:
# 4

# %%
a=5
b=10
c=15
a+b+c
# Out:
# 30

# %%
sum=(40+20+30)

# %%
sum
# Out:
# 90

# %%
a=5
b=5.3
c="str"

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# float

# %%
isinstance(5,int)
# Out:
# True

# %%
isinstance(4.5,int)
# Out:
# False

# %%
type(c)
# Out:
# str

# %%
#single line statement
p2=['a','b','c','d']
p2
# Out:
# ['a', 'b', 'c', 'd']

# %%
#multiple line statement  
p=30+70\
+20+90
p
# Out:
# 210

# %%
q=50/2\
/40/4
q
# Out:
# 0.15625

# %%
"Name"
len("Name")
# Out:
# 4
